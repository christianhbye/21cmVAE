# %% [markdown]
# This notebook shows an example of how to retrain 21cmVAE and the AuteoEncoder-based Emulator (from Appendix A).

# %%
from matplotlib import pyplot as plt
import sys
sys.path.append('..')
import VeryAccurateEmulator as VAE
# Out:
# 2021-11-08 17:03:46.171148: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/s/sievers/cbye/lib:/home/s/sievers/cbye/lib:/opt/slurm/lib64:/scinet/niagara/software/2019b/core/lib64
# 2021-11-08 17:03:46.171186: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Training 21cmVAE

# %%
emulator = VAE.VeryAccurateEmulator()
emulator.emulator.summary()
# Out:
# Model: "Emulator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  em_input (InputLayer)       [(None, 7)]               0
#
#  em_hidden_layer_0 (Dense)   (None, 288)               2304
#
#  em_hidden_layer_1 (Dense)   (None, 352)               101728
#
#  em_hidden_layer_2 (Dense)   (None, 288)               101664
#
#  em_hidden_layer_3 (Dense)   (None, 224)               64736
#
#  dense_16 (Dense)            (None, 451)               101475
#
# ...
# Total params: 371,907
# Trainable params: 371,907
# Non-trainable params: 0
# _________________________________________________________________
# ...

# %%
emulator.train()
# Out:
# Model Compiled: Emulator
# Epoch 1/350
# 96/96 [==============================] - 2s 12ms/step - loss: 6.4214e-05 - val_loss: 1.4853e-05 - lr: 0.0100
# Epoch 2/350
# 96/96 [==============================] - 1s 10ms/step - loss: 7.7357e-06 - val_loss: 4.5167e-06 - lr: 0.0100
# Epoch 3/350
# 96/96 [==============================] - 1s 11ms/step - loss: 3.2165e-06 - val_loss: 2.1669e-06 - lr: 0.0100
# Epoch 4/350
# 96/96 [==============================] - 1s 10ms/step - loss: 1.8912e-06 - val_loss: 1.3674e-06 - lr: 0.0100
# Epoch 5/350
# 96/96 [==============================] - 1s 10ms/step - loss: 1.3624e-06 - val_loss: 1.0369e-06 - lr: 0.0100
# Epoch 6/350
# 96/96 [==============================] - 1s 10ms/step - loss: 1.0075e-06 - val_loss: 1.0087e-06 - lr: 0.0100
# Epoch 7/350
# 96/96 [==============================] - 1s 10ms/step - loss: 8.6037e-07 - val_loss: 7.6087e-07 - lr: 0.0100
# Epoch 8/350
# ...

# %%
fig = plt.figure()
ax = fig.add_axes([0., 0., 1., 1.])
ax.plot(emulator.train_losses, label='Training')
ax.plot(emulator.val_losses, label='Validation')
ax.legend()
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_yscale('log')
plt.show()

# %%
rmse = emulator.compute_rms_error()
print(rmse.mean()*100)
# Out:
# 0.34438909497112036

# %% [markdown]
# ## Training the Autoencoder-based Emulator

# %%
ae_emulator = VAE.AutoEncoderEmulator()
ae_emulator.autoencoder.summary()
ae_emulator.emulator.summary()
ae_emulator.encoder.summary()
ae_emulator.decoder.summary()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "AutoEncoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_47 (InputLayer)       [(None, 451)]             0
#
#  encoder_hidden_layer_0 (Den  (None, 352)              159104
#  se)
#
#  z_mean (Dense)              (None, 9)                 3177
#
#  decoder_hidden_layer_0 (Den  (None, 32)               320
#  se)
#
#  decoder_hidden_layer_1 (Den  (None, 352)              11616
#  se)
#
#  dense_46 (Dense)            (None, 451)               159203
#
# ...
# Total params: 333,420
# Trainable params: 333,420
# Non-trainable params: 0
# _________________________________________________________________
# Model: "AE_Emulator"
# ...

# %%
ae_emulator.train()
# Out:
# Train Autoencoder
# Model Compiled: AutoEncoder
# Epoch 1/350
# 96/96 [==============================] - 1s 11ms/step - loss: 2.1869e-05 - val_loss: 2.6390e-06 - lr: 0.0100
# Epoch 2/350
# 96/96 [==============================] - 1s 9ms/step - loss: 1.6264e-06 - val_loss: 9.1414e-07 - lr: 0.0100
# Epoch 3/350
# 96/96 [==============================] - 1s 9ms/step - loss: 6.8227e-07 - val_loss: 5.1795e-07 - lr: 0.0100
# Epoch 4/350
# 96/96 [==============================] - 1s 10ms/step - loss: 4.7386e-07 - val_loss: 3.6831e-07 - lr: 0.0100
# Epoch 5/350
# 96/96 [==============================] - 1s 9ms/step - loss: 3.4155e-07 - val_loss: 3.4780e-07 - lr: 0.0100
# Epoch 6/350
# 96/96 [==============================] - 1s 9ms/step - loss: 2.8651e-07 - val_loss: 2.3195e-07 - lr: 0.0100
# Epoch 7/350
# 96/96 [==============================] - 1s 9ms/step - loss: 2.4430e-07 - val_loss: 5.5455e-07 - lr: 0.0100
# Epoch 8/350
# ...

# %%
fig = plt.figure()
ax1 = fig.add_axes([0., 0., 1., 1.])
ax1.plot(ae_emulator.ae_train_losses, label='Training')
ax1.plot(ae_emulator.ae_val_losses, label='Validation')
ax1.legend()
ax1.set_title('AutoEncoder')
ax1.set_ylabel('Loss')
ax2 = fig.add_axes([1.1, 0., 1., 1.])
ax2.plot(ae_emulator.em_train_losses, label='Training')
ax2.plot(ae_emulator.em_val_losses, label='Validation')
ax2.legend()
ax2.set_title('Emulator')
plt.setp([ax1, ax2], xlabel='Epoch', yscale='log')
plt.show()

# %%
rmse = ae_emulator.compute_rms_error()
print(rmse.mean()*100)
# Out:
# 0.4061104729771614
